# 2357         Penaborough  2018-01-14 15:58:48  54.10   432925983890
# 2358         Penaborough  2018-02-03 17:15:31  51.80  5383427508621
# 2359         Penaborough  2018-01-22 15:36:24  10.11  4129933467653
# 2360      Harringtonfort  2018-01-06 07:38:40  47.33  3849747342021
# 2361      Harringtonfort  2018-02-17 04:42:56  30.58  6835140871685
# 2362      Harringtonfort  2018-04-16 16:30:50  17.39  4023962353348
# 2363      Harringtonfort  2018-03-10 10:11:37  19.02  6717313402790
# 2364      Harringtonfort  2018-02-26 07:03:11  54.66  9201585331171
# 2365      Harringtonfort  2018-01-09 15:30:35  31.84  3730685356921
# 2366        West Heather  2018-03-12 04:22:26  26.55  7035849392668
# 2367        West Heather  2018-02-22 09:01:37  17.40  8702491506161
# 2368        West Heather  2018-02-22 01:46:43  33.38  5551691454078
# 2369        West Heather  2018-02-04 16:29:23  13.97  7118893881453
# 2370        West Heather  2018-04-18 19:33:12  46.60  3671003215967
# 2371        West Heather  2018-03-02 21:04:10  20.99  5766454453070
# 2372        West Heather  2018-03-06 20:06:51  48.11  2570548892682
# 2373        West Heather  2018-02-02 06:28:04  53.07  2462950442268
# 2374        West Heather  2018-05-07 19:22:15  44.94  4256853490277
#
#       driver_count   type
# 0                5  Urban
# 1                5  Urban
# 2                5  Urban
# 3                5  Urban
# 4                5  Urban
# 5                5  Urban
# 6                5  Urban
# 7                5  Urban
# 8                5  Urban
# 9                5  Urban
# 10               5  Urban
# 11               5  Urban
# 12               5  Urban
# 13               5  Urban
# 14               5  Urban
# 15               5  Urban
# 16               5  Urban
# 17               5  Urban
# 18               5  Urban
# 19               5  Urban
# 20               5  Urban
# 21               5  Urban
# 22               5  Urban
# 23               5  Urban
# 24              72  Urban
# 25              72  Urban
# 26              72  Urban
# 27              72  Urban
# 28              72  Urban
# 29              72  Urban
# ...            ...    ...
# 2345             1  Rural
# 2346             1  Rural
# 2347             1  Rural
# 2348             1  Rural
# 2349             1  Rural
# 2350             1  Rural
# 2351             1  Rural
# 2352             1  Rural
# 2353             1  Rural
# 2354             1  Rural
# 2355             6  Rural
# 2356             6  Rural
# 2357             6  Rural
# 2358             6  Rural
# 2359             6  Rural
# 2360             4  Rural
# 2361             4  Rural
# 2362             4  Rural
# 2363             4  Rural
# 2364             4  Rural
# 2365             4  Rural
# 2366             4  Rural
# 2367             4  Rural
# 2368             4  Rural
# 2369             4  Rural
# 2370             4  Rural
# 2371             4  Rural
# 2372             4  Rural
# 2373             4  Rural
# 2374             4  Rural
#
# [2375 rows x 6 columns]

# %%
# Split up our data into groups based upon 'city'
city_group = merge_table.groupby("city")

city_df = city_group.first()
# Find out how many rides and average fare in each city
city_df["Number of Rides"] = city_group["ride_id"].count()
city_df["Average Fare"] = city_group["fare"].mean()
city_df
# Out:
#                                      date   fare        ride_id  driver_count  \
# city
# Amandaburgh           2018-03-05 02:15:38  26.28   906850928986            12
# Barajasview           2018-01-15 02:59:07  19.52  8268107272481            26
# Barronchester         2018-01-27 03:08:01  27.79  6653622887913            11
# Bethanyland           2018-04-01 22:04:35  38.71  8221076873967            22
# Bradshawfurt          2018-03-06 21:44:53  19.74  6080367372860             7
# Brandonfort           2018-01-14 12:35:27  28.02  8100258078935            10
# Carriemouth           2018-02-25 08:26:25  32.37  6918425016992            52
# Williamsonville       2018-01-09 23:59:36  48.73  6507706939008             2
# Williamsstad          2018-01-23 17:51:24  19.62   125986195523            59
# Williamsview          2018-01-03 16:19:25  18.93  1979492913169            46
#
#                           type  Number of Rides  Average Fare
# city
# Amandaburgh              Urban               18     24.641667
# Barajasview              Urban               22     25.332273
# Barronchester         Suburban               16     36.422500
# Bethanyland           Suburban               18     32.956111
# Bradshawfurt             Rural               10     40.064000
# Brandonfort           Suburban               19     35.437368
# Carriemouth              Urban               27     28.314444
# Christopherfurt          Urban               27     24.501852
# Colemanland           Suburban               22     30.894545
# Davidfurt             Suburban               17     31.995882
# Deanville                Urban               19     25.842632
# East Aaronbury        Suburban                9     25.661111
# East Danielview       Suburban               17     31.560588
# East Kaylahaven          Urban               29     23.757931
# East Kentstad         Suburban               13     29.823077
# East Marymouth        Suburban               27     30.835185
# Erikaland                Urban               12     24.906667
# Garzaport                Rural                3     24.123333
# Grahamburgh              Urban               25     25.221200
# Grayville             Suburban               15     27.763333
# Harringtonfort           Rural                6     33.470000
# Huntermouth              Urban               24     28.993750
# Hurleymouth              Urban               28     25.891429
# Jerryton                 Urban               25     25.649200
# Jessicaport              Rural                6     36.013333
# Johnton                  Urban               21     26.785714
# Joneschester             Urban               25     22.289600
# Josephside            Suburban               27     32.858148
# Justinberg               Urban               30     23.694333
# Karenberg                Urban               17     26.340000
# ...                        ...              ...           ...
# South Evanton            Urban               31     26.726129
# South Jack               Urban               19     22.965263
# South Jennifer           Rural                7     35.264286
# South Karenland          Urban               38     26.535526
# South Latoya             Urban               19     20.093158
# South Marychester        Rural                8     41.870000
# South Michelleport       Urban               31     24.451613
# South Phillip            Urban               31     28.571290
# South Saramouth          Rural                4     36.160000
# South Teresa          Suburban               22     31.220455
# Taylorhaven              Rural                6     42.263333
# Valentineton             Urban               22     24.636364
# Veronicaberg          Suburban               17     32.828235
# Victoriaport          Suburban               14     27.780000
# West Angela              Urban               39     25.990000
# West Anthony             Urban               30     24.736667
# West Christopherberg     Urban               26     24.421154
# West Ericstad            Urban               18     22.347222
# West Gabriel             Urban               23     20.346087
# West Hannah           Suburban               21     29.547619
# West Heather             Rural                9     33.890000
# West Heidi               Urban               28     23.133929
# West Josephberg          Urban               26     21.720385
# West Kimmouth         Suburban               20     29.871500
# West Patrickchester      Urban               16     28.233125
# West Robert              Urban               31     25.123871
# West Samuelburgh         Urban               25     21.767600
# Williamsonville       Suburban               14     31.875000
# Williamsstad             Urban               23     24.362174
# Williamsview             Urban               20     26.599000
#
# [120 rows x 7 columns]

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
city_types = ["Urban", "Suburban", "Rural"]
urban_x = city_df.loc[city_df["type"] == "Urban", "Number of Rides"]
#print(urban_x.head())
urban_y = city_df.loc[city_df["type"] == "Urban", "Average Fare"]
#print(urban_y.head())
suburb_x = city_df.loc[city_df["type"] == "Suburban", "Number of Rides"]
suburb_y = city_df.loc[city_df["type"] == "Suburban", "Average Fare"]
rural_x = city_df.loc[city_df["type"] == "Rural", "Number of Rides"]
rural_y = city_df.loc[city_df["type"] == "Rural", "Average Fare"]
urban_drivers = city_df.loc[city_df["type"] == "Urban", "driver_count"]
suburb_drivers = city_df.loc[city_df["type"] == "Suburban", "driver_count"]
rural_drivers = city_df.loc[city_df["type"] == "Rural", "driver_count"]

# Build the scatter plots for each city type
urban_plot = plt.scatter(urban_x, urban_y, marker="o", facecolors="lightcoral", edgecolors="black",
            s=10*urban_drivers, alpha=0.5)
suburban_plot = plt.scatter(suburb_x, suburb_y, marker="o", facecolors="lightskyblue", edgecolors="black",
           s=10*suburb_drivers, alpha=0.5)
rural_plot = plt.scatter(rural_x, rural_y, marker="o", facecolors="gold", edgecolors="black",
           s=10*rural_drivers, alpha=0.5)

# Incorporate the other graph properties
#plt.xlim(0, 65)
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare (Dollars)")

# Create a legend
plt.legend((urban_plot, suburban_plot, rural_plot),
           ('Urban', 'Suburban', 'Rural'))

# Incorporate a text label regarding circle size
plt.text(45,35,'Note:\nCircle size correlates to drivers per city')

# Save Figure
plt.savefig("Images/PyberRideSharingData.png")

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
city_types = ["Urban", "Suburban", "Rural"]
# Split up our data into groups based upon 'type'
type_groups = merge_table.groupby('type')
# Find out how many rides for each city type
type_trips = type_groups['ride_id'].count() * type_groups['fare'].mean()
type_df = city_group.first()
type_df["Number of Rides"] = type_groups["ride_id"].count()
type_df["Average Fare"] = type_groups["fare"].mean()
#print(type_df.head())
type_table = pd.DataFrame(type_trips)
type_group = merge_table.groupby("type")
total_fare = [type_table.loc["Urban",0], type_table.loc["Suburban",0], type_table.loc["Rural",0]]
colors = ["lightcoral","lightskyblue","gold"]
explode = (0.1,0,0)

# Build Pie Chart
#total_fare
plt.figure(figsize=(5,5))
plt.pie(total_fare, explode=explode, labels=city_types, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=280)
plt.title("% of Total Fares by City Type")

plt.axis("equal")

# Save Figure
plt.savefig("Images/PyberFarePie.png")

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
total_rides = type_groups['ride_id'].count()
#total_rides

# Build Pie Chart
ride_table = pd.DataFrame(total_rides)
#print(ride_table)
ride_table.loc["Urban"]
ride_pie = [ride_table.loc["Urban"], ride_table.loc["Suburban"], ride_table.loc["Rural"]]
#ride_pie
plt.figure(figsize=(5,5))
plt.pie(ride_pie, explode=explode, labels=city_types, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=260)
plt.title("% of Total Rides by City Type")

# Save Figure
plt.savefig("Images/PyberRidePie.png")

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
city_type_group = city_data.groupby('type')
total_drivers = city_type_group['driver_count'].sum()
#total_drivers

# Build Pie Charts
driver_table = pd.DataFrame(total_drivers)
#print(driver_table)
driver_table.loc["Urban"]
driver_pie = [driver_table.loc["Urban"], driver_table.loc["Suburban"], driver_table.loc["Rural"]]
plt.figure(figsize=(5,5))
plt.pie(driver_pie, explode=explode, labels=city_types, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=240)
plt.title("% of Total Drivers by City Type")

# Save Figure
plt.savefig("Images/PyberDriverPie.png")

# %%
# Show Figure
plt.show()

# %%
# OBSERVABLE TRENDS
# 1. Urban cities have cheaper fares, with 68.4% of the total rides, but only 62.7% of total fares.
# 2. Rural city drivers are busier, with 2.6% of the total drivers and 5.3% of the total rides.
# 3. Rural cities have the largest range of average fare, ranging from under $25 to over $40.
